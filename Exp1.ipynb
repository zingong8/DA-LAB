# %%
import pandas as pd
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
car_sales = '/content/data.csv'
df = pd.read_csv(car_sales)
a = pd.read_csv(car_sales)

# %%
df.head(10)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
# 5  BMW    1 Series  2012  premium unleaded (required)      230.0
# 6  BMW    1 Series  2012  premium unleaded (required)      300.0
# 7  BMW    1 Series  2012  premium unleaded (required)      300.0
# 8  BMW    1 Series  2012  premium unleaded (required)      230.0
# 9  BMW    1 Series  2013  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# ...

# %%
print('no of rows:',df.shape[0])
inital_count=df.shape[0]
print('no of columns:',df.shape[1])
print('no of nan/missing values',df.isnull().sum().sum())
print('              ')
datatypes = df.dtypes
print(datatypes)
print("       ")
print('No of null values',df.isnull().sum())# shows null values by column, counts number of true values returned from isnull function
# Out:
# no of rows: 11914
# no of columns: 16
# no of nan/missing values 3850
#
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object
#
# No of null values Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# ...

# %%
# removing na values
df=df.dropna(axis=0)

# %%
print(df.isnull().sum())
print('   ')
print('Shape of dataframe: ',df.shape)
final_count=df.shape[0]
print('No of rows dropped',inital_count-final_count)
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Market Category      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64
#
# Shape of dataframe:  (8084, 16)
# No of rows dropped 3830

# %%
print(df['Make'].unique())
print("               ")
print('Total number of Manufactures = ',len(df['Make'].unique()))
# Out:
# ['BMW' 'Audi' 'FIAT' 'Mercedes-Benz' 'Chrysler' 'Nissan' 'Volvo' 'Mazda'
#  'Mitsubishi' 'Ferrari' 'Alfa Romeo' 'McLaren' 'Maybach' 'Porsche'
#  'Toyota' 'Saab' 'GMC' 'Hyundai' 'Honda' 'Cadillac' 'Bentley' 'Ford'
#  'Oldsmobile' 'Chevrolet' 'Dodge' 'Lamborghini' 'Lincoln' 'Pontiac'
#  'Subaru' 'Volkswagen' 'Spyker' 'Kia' 'Acura' 'Plymouth' 'Rolls-Royce'
#  'Maserati' 'Lexus' 'Aston Martin' 'Land Rover' 'Lotus' 'Buick' 'Infiniti'
#  'Scion' 'Genesis' 'Suzuki' 'HUMMER' 'Bugatti']
#
# Total number of Manufactures =  47

# %%
df.describe()
# Out:
#               Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  8084.000000  8084.000000       8084.000000      8084.000000
# mean   2012.058634   274.642751          5.778080         3.414151
# std       6.317981   115.003475          1.886088         0.898087
# min    1990.000000    55.000000          0.000000         2.000000
# 25%    2010.000000   192.000000          4.000000         2.000000
# 50%    2015.000000   264.000000          6.000000         4.000000
# 75%    2016.000000   320.000000          6.000000         4.000000
# max    2017.000000  1001.000000         16.000000         4.000000
#
#        highway MPG     city mpg   Popularity          MSRP
# count  8084.000000  8084.000000  8084.000000  8.084000e+03
# mean     26.650915    19.553686  1499.397823  5.007267e+04
# std       7.720473     7.159964  1413.855615  7.029313e+04
# min      12.000000     7.000000     2.000000  2.000000e+03
# 25%      22.000000    16.000000   549.000000  2.591875e+04
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8084 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               8084 non-null   object
#  1   Model              8084 non-null   object
#  2   Year               8084 non-null   int64
#  3   Engine Fuel Type   8084 non-null   object
#  4   Engine HP          8084 non-null   float64
#  5   Engine Cylinders   8084 non-null   float64
#  6   Transmission Type  8084 non-null   object
#  7   Driven_Wheels      8084 non-null   object
#  8   Number of Doors    8084 non-null   float64
#  9   Market Category    8084 non-null   object
#  10  Vehicle Size       8084 non-null   object
#  11  Vehicle Style      8084 non-null   object
#  12  highway MPG        8084 non-null   int64
#  13  city mpg           8084 non-null   int64
#  14  Popularity         8084 non-null   int64
#  15  MSRP               8084 non-null   int64
# ...

# %%
#general info
most_expensive_car=df.loc[df['MSRP'].idxmax()]
print(most_expensive_car)
print('               ')
print('               ')
highest_hp=df.loc[[df['Engine HP'].idxmax()]]
# Out:
# Make                                     Bugatti
# Model                                Veyron 16.4
# Year                                        2008
# Engine Fuel Type     premium unleaded (required)
# Engine HP                                 1001.0
# Engine Cylinders                            16.0
# Transmission Type               AUTOMATED_MANUAL
# Driven_Wheels                    all wheel drive
# Number of Doors                              2.0
# Market Category          Exotic,High-Performance
# Vehicle Size                             Compact
# Vehicle Style                              Coupe
# highway MPG                                   14
# city mpg                                       8
# Popularity                                   820
# MSRP                                     2065902
# Name: 11362, dtype: object

# %%
highest_hp
# Out:
#           Make        Model  Year             Engine Fuel Type  Engine HP  \
# 11362  Bugatti  Veyron 16.4  2008  premium unleaded (required)     1001.0
#
#        Engine Cylinders Transmission Type    Driven_Wheels  Number of Doors  \
# 11362              16.0  AUTOMATED_MANUAL  all wheel drive              2.0
#
#                Market Category Vehicle Size Vehicle Style  highway MPG  \
# 11362  Exotic,High-Performance      Compact         Coupe           14
#
#        city mpg  Popularity     MSRP
# 11362         8         820  2065902

# %%
by_make=df.groupby(['Make'])['Make'].count()
print(by_make)
print('           ')
print('           ')
max_carsold=by_make.idxmax()
print('The company which sold the highest car is',max_carsold,'and the number of units sold are',by_make[max_carsold])
# Out:
# Make
# Acura            252
# Alfa Romeo         5
# Aston Martin      93
# Audi             328
# BMW              334
# Bentley           74
# Bugatti            3
# Buick            125
# Cadillac         397
# Chevrolet        614
# Chrysler         108
# Dodge            320
# FIAT              38
# Ferrari           68
# Ford             492
# GMC              270
# Genesis            3
# HUMMER            17
# Honda            282
# Hyundai          214
# Infiniti         330
# Kia              109
# Lamborghini       52
# Land Rover       143
# Lexus            202
# Lincoln          156
# Lotus             29
# Maserati          58
# Maybach           16
# Mazda            239
# McLaren            5
# Mercedes-Benz    352
# Mitsubishi       125
# Nissan           308
# Oldsmobile         3
# Plymouth          39
# Pontiac           77
# Porsche          136
# Rolls-Royce       31
# Saab             111
# Scion             48
# Spyker             3
# Subaru           214
# ...

# %%
by_make1=df.groupby(['Transmission Type'])['Transmission Type'].count()
print(by_make1)
# Out:
# Transmission Type
# AUTOMATED_MANUAL     610
# AUTOMATIC           5761
# DIRECT_DRIVE          15
# MANUAL              1695
# UNKNOWN                3
# Name: Transmission Type, dtype: int64

# %%
#Calculating cc of each car
df['cc']=df['Engine Cylinders']*565
df['cc']=df['cc']/1000
df['cc']=df['cc'].apply(np.ceil)

# %%
#filtering
df[(df['Engine HP']>300) & (df['Engine Cylinders']>6) & (df['city mpg']>19)]
# Out:
#             Make                  Model  Year  Engine Fuel Type  Engine HP  \
# 1466    Chrysler                  Aspen  2009  regular unleaded      385.0
# 4138    Cadillac        Escalade Hybrid  2011  regular unleaded      332.0
# 4139    Cadillac        Escalade Hybrid  2011  regular unleaded      332.0
# 4140    Cadillac        Escalade Hybrid  2011  regular unleaded      332.0
# 4141    Cadillac        Escalade Hybrid  2011  regular unleaded      332.0
# 4142    Cadillac        Escalade Hybrid  2012  regular unleaded      332.0
# 4143    Cadillac        Escalade Hybrid  2012  regular unleaded      332.0
# 4144    Cadillac        Escalade Hybrid  2012  regular unleaded      332.0
# 4145    Cadillac        Escalade Hybrid  2012  regular unleaded      332.0
# 4146    Cadillac        Escalade Hybrid  2013  regular unleaded      332.0
# 4147    Cadillac        Escalade Hybrid  2013  regular unleaded      332.0
# ...

# %%
sns.relplot('Engine Cylinders','Engine HP',data=df,hue='Driven_Wheels',style='Vehicle Size')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.relplot('Engine Cylinders','Engine HP',data=df,hue='Driven_Wheels',style='Vehicle Size',col='Transmission Type',col_wrap=3)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.catplot('Vehicle Size','Engine Cylinders',data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.catplot(x='Engine HP',kind='box',data=df)

# %%
sns.relplot(x='highway MPG',y='Engine HP',data=df)

# %%
sns.heatmap(df.corr())

# %%
df2=df[(df['Make']=='BMW')]
df2=df2[['Make','Transmission Type']]
print(df2)
df['Transmission Type'].unique()
# Out:
#       Make Transmission Type
# 0      BMW            MANUAL
# 1      BMW            MANUAL
# 2      BMW            MANUAL
# 3      BMW            MANUAL
# 4      BMW            MANUAL
# ...    ...               ...
# 11901  BMW            MANUAL
# 11902  BMW  AUTOMATED_MANUAL
# 11903  BMW            MANUAL
# 11904  BMW            MANUAL
# 11905  BMW            MANUAL
#
# [334 rows x 2 columns]
# array(['MANUAL', 'AUTOMATIC', 'AUTOMATED_MANUAL', 'DIRECT_DRIVE',
#        'UNKNOWN'], dtype=object)

# %%
sns.histplot(data=df2, x="Transmission Type")
